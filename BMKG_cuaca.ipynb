# %% [markdown]
# <a href="https://colab.research.google.com/github/defittri01/BMKG-cuaca/blob/main/BMKG_cuaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium &> /dev/null
# !apt-get update  &> /dev/null # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver &> /dev/null
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin &> /dev/null

# !git clone https://github.com/defittri01/BMKG-cuaca.git &> /dev/null

# %cd '/content/BMKG-cuaca/'
import BMKG_Cuaca
# Out:
# /content/BMKG-cuaca

# %% [markdown]
# ## Login

# %%
BMKG_cuaca = BMKG_Cuaca.BMKGCuaca()
BMKG_cuaca.login()
# Out:
# chrome is opened successfully
# E-mail: sagosiswa@gmail.com
# Password: ··········

# %%
BMKG_cuaca.solve_login_capt()
# Out:
# solve captcha: 74MYMP
# Login success

# %% [markdown]
# ## Set parameter

# %%
provinsi = 'Jawa Tengah'
stasiun = 'Stasiun Meteorologi Maritim Tegal'

BMKG_cuaca.set_parameter(provinsi, stasiun)
# Out:
# Jenis stasiun: UPT
# Parameter dipilih: Curah hujan (RR)
# Parameter dipilih: Kecepatan angin rata-rata (ff_avg)
# Parameter dipilih: Kelembaban rata-rata (RH_avg)
# Parameter dipilih: Lamanya penyinaran matahari (ss)
# Parameter dipilih: Temperatur rata-rata (T_avg)
# Provinsi: Jawa Tengah
# No/Nama Stasiun: Stasiun Meteorologi Maritim Tegal

# %% [markdown]
# ## Collecting data

# %% [markdown]
# Tiap Tahun

# %%
tahun = '2016'
month_start = 1     # urutan bulan
month_end   = 2     # urutan bulan
half_month  = False  # True untuk data tiap setengah bulan
delay       = 6     # detik; min. 3 detik

BMKG_cuaca.collect_data(month_start, month_end, tahun, half_month, delay)
BMKG_cuaca.download_data(tahun)

# %% [markdown]
# Beberapa Tahun

# %%
tahun = ['2017', '2018'] 

for th in tahun:  
  month_start = 1       # urutan bulan
  month_end   = 2       # urutan bulan
  half_month  = True   # True untuk data tiap setengah bulan
  delay       = 6       # detik

  BMKG_cuaca.collect_data(month_start, month_end, th, half_month, delay)
  BMKG_cuaca.download_data(th)
# Out:
# mengunduh data  01-01-2017  s.d.  15-01-2017
# mengunduh data  16-01-2017  s.d.  31-01-2017
# mengunduh data  01-02-2017  s.d.  15-02-2017
# mengunduh data  16-02-2017  s.d.  28-02-2017
# 0.9336210166666666 menit
# mengunduh data  01-01-2018  s.d.  15-01-2018
# mengunduh data  16-01-2018  s.d.  31-01-2018
# mengunduh data  01-02-2018  s.d.  15-02-2018
# mengunduh data  16-02-2018  s.d.  28-02-2018
# 0.9408305 menit
